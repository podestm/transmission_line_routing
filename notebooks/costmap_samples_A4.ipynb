# %% [markdown]
# ### A4 — Cost Map

# %%
"""
Build and compare two square costmaps for A4.
Each scenario uses its own config module and both outputs share one color scale.
"""

import sys
from pathlib import Path

sys.path.insert(0, str(Path("../").resolve()))

from src.costmap_builder import build_costmaps_for_scenarios
from src.map_plot import plot_costmaps_side_by_side

AREA_LABEL = "A4"
GEOJSON_PATH = Path("../data_A4.geojson")
GPKG_PATH = Path("../data/raw/ZABAGED_RESULTS.gpkg")
OUTPUT_DIR = Path("../data/processed/A4")
CELL_SIZE = 50

SCENARIOS = [
    {"module": "config_costs_A4_1", "label": "A4 config 1", "export_prefix": "costmap_A4_1"},
    {"module": "config_costs_A4_2", "label": "A4 config 2", "export_prefix": "costmap_A4_2"},
]

scenario_results = build_costmaps_for_scenarios(
    SCENARIOS,
    GEOJSON_PATH,
    GPKG_PATH,
    OUTPUT_DIR,
    CELL_SIZE,
)
plot_costmaps_side_by_side(scenario_results, AREA_LABEL)
# Out:
#   [cache] Loading costmap_A4_1_50m.gpkg from disk (use force_rebuild=True to rebuild)
#   [cache] Loading costmap_A4_2_50m.gpkg from disk (use force_rebuild=True to rebuild)

# %%
"""
Run and compare Dijkstra on both A4 costmaps.
Both scenarios use the same start/goal and shared visualization scaling.
"""

from src.dijkstra import run_dijkstra_for_scenarios
from src.map_plot import plot_dijkstra_side_by_side

START_LONLAT = (17.54, 49.14)
GOAL_LONLAT = (17.65, 49.21)

EXCLUSION_PENALTY = 10.0
MAX_JUMPS = 10
MAX_JUMP_EDGE_M = 200.0
TURN_PENALTY = 10

route_results = run_dijkstra_for_scenarios(
    scenario_results,
    START_LONLAT,
    GOAL_LONLAT,
    EXCLUSION_PENALTY,
    MAX_JUMPS,
    TURN_PENALTY,
    max_jump_edge_m=MAX_JUMP_EDGE_M,
)

plot_dijkstra_side_by_side(
    route_results,
    AREA_LABEL,
    START_LONLAT,
    GOAL_LONLAT,
    EXCLUSION_PENALTY,
    MAX_JUMPS,
    TURN_PENALTY,
    max_jump_edge_m=MAX_JUMP_EDGE_M,
)
# Out:
# ============================================================
# DIJKSTRA A4 config 1
# ============================================================
# Start coord: (17.54, 49.14) -> square cell_id=4690
# Goal  coord: (17.65, 49.21) -> square cell_id=28494
# Start and Goal are outside exclusion zones.
#   [A4 config 1] Building graph (30,518 nodes)... 114,402 direct + 510,604 jump edges (4,908 blocked by can_cross) (17.3 s)
#   [A4 config 1] Turn penalty active: 9 dirs x 11 jumps = 3,021,282 states (~49 MB)
#   [A4 config 1] Running Dijkstra (3,021,282 states)... 2,424,648 expansions (141.3 s)
# Total cost: 643.2 | 219 cells | ~13,428 m | jumps: 3x | turns: 8 | 159.12 s total
#
# ============================================================
# DIJKSTRA A4 config 2
# ============================================================
# Start coord: (17.54, 49.14) -> square cell_id=4690
# Goal  coord: (17.65, 49.21) -> square cell_id=28494
# Start and Goal are outside exclusion zones.
#   [A4 config 2] Building graph (30,518 nodes)... 114,402 direct + 510,604 jump edges (4,908 blocked by can_cross) (18.5 s)
#   [A4 config 2] Turn penalty active: 9 dirs x 11 jumps = 3,021,282 states (~49 MB)
#   [A4 config 2] Running Dijkstra (3,021,282 states)... 2,390,378 expansions (136.8 s)
# Total cost: 887.9 | 272 cells | ~16,658 m | jumps: 10x | turns: 16 | 155.94 s total

# %%
"""
PPO block - inference on the 50 m costmap with forced coarse steps.
Each action moves ~300 m (virtual 8-directional coarse grid) to reduce zigzagging.
Uses route_results from block 3 (same start/goal, same 50 m costmap).
"""
import importlib
import sys
from pathlib import Path

sys.path.insert(0, str(Path("../").resolve()))

import ppo_routing_cnn  # noqa: F401 – required so MaskablePPO can deserialise the saved model
import src.ppo_inference as ppo_inference

importlib.reload(ppo_inference)

AREA_LABEL = globals().get("AREA_LABEL", "A4")
EXCLUSION_PENALTY = globals().get("EXCLUSION_PENALTY", 10)
MAX_JUMPS = globals().get("MAX_JUMPS", 10)
TURN_PENALTY = globals().get("TURN_PENALTY", 1.0)

MODEL_PATH = Path("../ppo_models/coarse300_12km_v4/ppo_routing_final")
PPO_SAMPLE_COUNT = 2
PPO_MAX_ATTEMPTS = 50
PPO_MAX_STEPS = 200
COARSE_STEP_M = 300

ppo_sample_results = ppo_inference.run_ppo_samples_for_scenarios(
    route_results,
    model_path=MODEL_PATH,
    n_samples=PPO_SAMPLE_COUNT,
    max_attempts=PPO_MAX_ATTEMPTS,
    exclusion_penalty=EXCLUSION_PENALTY,
    max_jumps=MAX_JUMPS,
    turn_penalty=TURN_PENALTY,
    max_steps=PPO_MAX_STEPS,
    coarse_step_m=COARSE_STEP_M,
)
# Out:
#   [A4 config 1] Building coarse graph (300 m steps)...
#   Coarse graph (300 m): 30416/30518 nodes reachable, avg 7.1 directions/node
#   Detected torch.compile() artifact - remapping _orig_mod keys...
#   [A4 config 1 attempt 1] PPO: FAILED to reach goal in 200 steps (1.64s)
#   [A4 config 1 attempt 2] PPO: FAILED to reach goal in 200 steps (1.09s)
#   [A4 config 1 attempt 3] PPO: FAILED to reach goal in 200 steps (1.16s)
#   [A4 config 1 attempt 4] PPO: FAILED to reach goal in 200 steps (1.06s)
#   [A4 config 1 attempt 5] PPO: FAILED to reach goal in 200 steps (1.10s)
#   [A4 config 1 attempt 6] PPO: FAILED to reach goal in 200 steps (1.06s)
#   [A4 config 1 attempt 7] PPO: FAILED to reach goal in 181 steps (1.06s)
#   [A4 config 1 attempt 8] PPO: FAILED to reach goal in 200 steps (1.05s)
#   [A4 config 1 attempt 9] PPO: FAILED to reach goal in 55 steps (0.35s)
#   [A4 config 1 attempt 10] PPO: FAILED to reach goal in 200 steps (1.25s)
#   [A4 config 1 attempt 11] PPO: FAILED to reach goal in 200 steps (1.09s)
#   [A4 config 1 attempt 12] PPO: FAILED to reach goal in 90 steps (0.47s)
#   [A4 config 1 attempt 13] PPO: FAILED to reach goal in 200 steps (1.06s)
#   [A4 config 1 attempt 14] PPO: cost=353.5 | 114 cells | ~34,947 m | jumps=0 | turns=81 | steps=113 | 0.55s
#   [A4 config 1 attempt 15] PPO: FAILED to reach goal in 200 steps (1.05s)
#   [A4 config 1 attempt 16] PPO: FAILED to reach goal in 200 steps (1.28s)
#   [A4 config 1 attempt 17] PPO: FAILED to reach goal in 200 steps (1.03s)
#   [A4 config 1 attempt 18] PPO: FAILED to reach goal in 200 steps (1.12s)
#   [A4 config 1 attempt 19] PPO: FAILED to reach goal in 34 steps (0.23s)
#   [A4 config 1 attempt 20] PPO: FAILED to reach goal in 113 steps (0.67s)
#   [A4 config 1 attempt 21] PPO: FAILED to reach goal in 200 steps (1.05s)
#   [A4 config 1 attempt 22] PPO: FAILED to reach goal in 79 steps (0.51s)
#   [A4 config 1 attempt 23] PPO: FAILED to reach goal in 200 steps (1.40s)
#   [A4 config 1 attempt 24] PPO: FAILED to reach goal in 200 steps (1.12s)
#   [A4 config 1 attempt 25] PPO: FAILED to reach goal in 200 steps (1.21s)
#   [A4 config 1 attempt 26] PPO: FAILED to reach goal in 200 steps (1.11s)
#   [A4 config 1 attempt 27] PPO: FAILED to reach goal in 200 steps (1.20s)
#   [A4 config 1 attempt 28] PPO: FAILED to reach goal in 200 steps (1.17s)
#   [A4 config 1 attempt 29] PPO: FAILED to reach goal in 200 steps (1.12s)
#   [A4 config 1 attempt 30] PPO: FAILED to reach goal in 200 steps (1.12s)
#   [A4 config 1 attempt 31] PPO: FAILED to reach goal in 200 steps (1.14s)
#   [A4 config 1 attempt 32] PPO: FAILED to reach goal in 200 steps (1.03s)
#   [A4 config 1 attempt 33] PPO: FAILED to reach goal in 76 steps (0.41s)
#   [A4 config 1 attempt 34] PPO: FAILED to reach goal in 89 steps (0.63s)
#   [A4 config 1 attempt 35] PPO: FAILED to reach goal in 200 steps (1.06s)
#   [A4 config 1 attempt 36] PPO: FAILED to reach goal in 200 steps (1.25s)
#   [A4 config 1 attempt 37] PPO: FAILED to reach goal in 200 steps (1.11s)
#   [A4 config 1 attempt 38] PPO: FAILED to reach goal in 200 steps (1.21s)
#   [A4 config 1 attempt 39] PPO: FAILED to reach goal in 53 steps (0.27s)
#   [A4 config 1 attempt 40] PPO: FAILED to reach goal in 154 steps (0.85s)
#   [A4 config 1 attempt 41] PPO: FAILED to reach goal in 200 steps (1.06s)
#   [A4 config 1 attempt 42] PPO: FAILED to reach goal in 200 steps (1.10s)
#   [A4 config 1 attempt 43] PPO: FAILED to reach goal in 69 steps (0.54s)
#   [A4 config 1 attempt 44] PPO: FAILED to reach goal in 200 steps (1.30s)
#   [A4 config 1 attempt 45] PPO: FAILED to reach goal in 200 steps (1.10s)
#   [A4 config 1 attempt 46] PPO: FAILED to reach goal in 200 steps (1.17s)
#   [A4 config 1 attempt 47] PPO: FAILED to reach goal in 200 steps (1.12s)
#   [A4 config 1 attempt 48] PPO: FAILED to reach goal in 200 steps (1.13s)
#   [A4 config 1 attempt 49] PPO: FAILED to reach goal in 200 steps (1.16s)
#   [A4 config 1 attempt 50] PPO: FAILED to reach goal in 200 steps (1.34s)
#   [A4 config 1] 1 unique successful routes from 50 attempts
#   [A4 config 2] Building coarse graph (300 m steps)...
#   Coarse graph (300 m): 30416/30518 nodes reachable, avg 7.1 directions/node
#   Detected torch.compile() artifact - remapping _orig_mod keys...
#   [A4 config 2 attempt 1] PPO: FAILED to reach goal in 200 steps (1.06s)
#   [A4 config 2 attempt 2] PPO: FAILED to reach goal in 200 steps (1.05s)
#   [A4 config 2 attempt 3] PPO: FAILED to reach goal in 200 steps (1.04s)
#   [A4 config 2 attempt 4] PPO: FAILED to reach goal in 200 steps (1.11s)
#   [A4 config 2 attempt 5] PPO: FAILED to reach goal in 200 steps (1.15s)
#   [A4 config 2 attempt 6] PPO: FAILED to reach goal in 200 steps (1.04s)
#   [A4 config 2 attempt 7] PPO: FAILED to reach goal in 200 steps (1.11s)
#   [A4 config 2 attempt 8] PPO: FAILED to reach goal in 200 steps (1.12s)
#   [A4 config 2 attempt 9] PPO: FAILED to reach goal in 200 steps (0.98s)
#   [A4 config 2 attempt 10] PPO: FAILED to reach goal in 21 steps (0.13s)
#   [A4 config 2 attempt 11] PPO: FAILED to reach goal in 200 steps (1.11s)
#   [A4 config 2 attempt 12] PPO: FAILED to reach goal in 200 steps (1.13s)
#   [A4 config 2 attempt 13] PPO: cost=1428.6 | 201 cells | ~61,444 m | jumps=0 | turns=154 | steps=200 | 1.18s
#   [A4 config 2 attempt 14] PPO: FAILED to reach goal in 200 steps (1.01s)
#   [A4 config 2 attempt 15] PPO: FAILED to reach goal in 200 steps (1.12s)
#   [A4 config 2 attempt 16] PPO: FAILED to reach goal in 200 steps (1.00s)
#   [A4 config 2 attempt 17] PPO: FAILED to reach goal in 200 steps (1.11s)
#   [A4 config 2 attempt 18] PPO: FAILED to reach goal in 200 steps (1.00s)
#   [A4 config 2 attempt 19] PPO: FAILED to reach goal in 200 steps (1.01s)
#   [A4 config 2 attempt 20] PPO: FAILED to reach goal in 200 steps (1.20s)
#   [A4 config 2 attempt 21] PPO: FAILED to reach goal in 200 steps (1.18s)
#   [A4 config 2 attempt 22] PPO: FAILED to reach goal in 200 steps (0.99s)
#   [A4 config 2 attempt 23] PPO: FAILED to reach goal in 200 steps (1.25s)
#   [A4 config 2 attempt 24] PPO: FAILED to reach goal in 200 steps (1.05s)
#   [A4 config 2 attempt 25] PPO: FAILED to reach goal in 200 steps (1.14s)
#   [A4 config 2 attempt 26] PPO: FAILED to reach goal in 200 steps (0.97s)
#   [A4 config 2 attempt 27] PPO: FAILED to reach goal in 200 steps (1.05s)
#   [A4 config 2 attempt 28] PPO: FAILED to reach goal in 200 steps (1.09s)
#   [A4 config 2 attempt 29] PPO: FAILED to reach goal in 200 steps (1.01s)
#   [A4 config 2 attempt 30] PPO: FAILED to reach goal in 200 steps (1.14s)
#   [A4 config 2 attempt 31] PPO: FAILED to reach goal in 200 steps (1.21s)
#   [A4 config 2 attempt 32] PPO: FAILED to reach goal in 200 steps (1.07s)
#   [A4 config 2 attempt 33] PPO: FAILED to reach goal in 200 steps (1.23s)
#   [A4 config 2 attempt 34] PPO: FAILED to reach goal in 200 steps (1.21s)
#   [A4 config 2 attempt 35] PPO: FAILED to reach goal in 200 steps (1.21s)
#   [A4 config 2 attempt 36] PPO: FAILED to reach goal in 200 steps (1.28s)
#   [A4 config 2 attempt 37] PPO: FAILED to reach goal in 200 steps (1.21s)
#   [A4 config 2 attempt 38] PPO: FAILED to reach goal in 200 steps (1.26s)
#   [A4 config 2 attempt 39] PPO: FAILED to reach goal in 200 steps (1.24s)
#   [A4 config 2 attempt 40] PPO: FAILED to reach goal in 200 steps (1.08s)
#   [A4 config 2 attempt 41] PPO: FAILED to reach goal in 200 steps (1.12s)
#   [A4 config 2 attempt 42] PPO: FAILED to reach goal in 200 steps (1.22s)
#   [A4 config 2 attempt 43] PPO: FAILED to reach goal in 200 steps (1.05s)
#   [A4 config 2 attempt 44] PPO: FAILED to reach goal in 200 steps (1.05s)
#   [A4 config 2 attempt 45] PPO: FAILED to reach goal in 200 steps (1.04s)
#   [A4 config 2 attempt 46] PPO: FAILED to reach goal in 200 steps (1.01s)
#   [A4 config 2 attempt 47] PPO: FAILED to reach goal in 200 steps (1.15s)
#   [A4 config 2 attempt 48] PPO: FAILED to reach goal in 200 steps (1.17s)
#   [A4 config 2 attempt 49] PPO: FAILED to reach goal in 200 steps (1.03s)
#   [A4 config 2 attempt 50] PPO: FAILED to reach goal in 200 steps (1.15s)
#   [A4 config 2] 1 unique successful routes from 50 attempts

# %%
import src.ppo_visualization as ppo_visualization

ppo_visualization.plot_dijkstra_with_ppo_samples(
    ppo_sample_results,
    AREA_LABEL,
    START_LONLAT,
    GOAL_LONLAT,
)
