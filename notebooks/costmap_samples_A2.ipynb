# %% [markdown]
# ### A2 — Cost Map

# %%
"""
Build and compare two square costmaps for A2.
Each scenario uses its own config module and both outputs share one color scale.
"""

import sys
from pathlib import Path

sys.path.insert(0, str(Path("../").resolve()))

from src.costmap_builder import build_costmaps_for_scenarios
from src.map_plot import plot_costmaps_side_by_side

AREA_LABEL = "A2"
GEOJSON_PATH = Path("../data_A2.geojson")
GPKG_PATH = Path("../data/raw/ZABAGED_RESULTS.gpkg")
OUTPUT_DIR = Path("../data/processed/A2")
CELL_SIZE = 50

SCENARIOS = [
    {"module": "config_costs_A2_1", "label": "A2 config 1", "export_prefix": "costmap_A2_1"},
    {"module": "config_costs_A2_2", "label": "A2 config 2", "export_prefix": "costmap_A2_2"},
]

scenario_results = build_costmaps_for_scenarios(
    SCENARIOS,
    GEOJSON_PATH,
    GPKG_PATH,
    OUTPUT_DIR,
    CELL_SIZE,
    # force_rebuild=True,
)
plot_costmaps_side_by_side(scenario_results, AREA_LABEL)
# Out:
#   [cache] Loading costmap_A2_1_50m.gpkg from disk (use force_rebuild=True to rebuild)
#   [cache] Loading costmap_A2_2_50m.gpkg from disk (use force_rebuild=True to rebuild)

# %%
"""
Run and compare Dijkstra on both A2 costmaps.
Both scenarios use the same start/goal and shared visualization scaling.
"""

from src.dijkstra import run_dijkstra_for_scenarios
from src.map_plot import plot_dijkstra_side_by_side

START_LONLAT = (17.79, 49.18)
GOAL_LONLAT = (17.90, 49.24)

EXCLUSION_PENALTY = 10.0
MAX_JUMPS = 20
MAX_JUMP_EDGE_M = 100.0
TURN_PENALTY = 20

route_results = run_dijkstra_for_scenarios(
    scenario_results,
    START_LONLAT,
    GOAL_LONLAT,
    EXCLUSION_PENALTY,
    MAX_JUMPS,
    TURN_PENALTY,
    max_jump_edge_m=MAX_JUMP_EDGE_M,
)

plot_dijkstra_side_by_side(
    route_results,
    AREA_LABEL,
    START_LONLAT,
    GOAL_LONLAT,
    EXCLUSION_PENALTY,
    MAX_JUMPS,
    TURN_PENALTY,
    max_jump_edge_m=MAX_JUMP_EDGE_M,
)
# Out:
# ============================================================
# DIJKSTRA A2 config 1
# ============================================================
# Start coord: (17.79, 49.18) -> square cell_id=1981
# Goal  coord: (17.9, 49.24) -> square cell_id=24324
# Start and Goal are outside exclusion zones.
#   [A2 config 1] Building graph (33,239 nodes)... 122,827 direct + 28,937 jump edges (1,151 blocked by can_cross) (3.3 s)
#   [A2 config 1] Turn penalty active: 9 dirs x 21 jumps = 6,282,171 states (~102 MB)
#   [A2 config 1] Running Dijkstra (6,282,171 states)... 3,476,091 expansions (57.6 s)
# Total cost: 2365.7 | 257 cells | ~15,041 m | jumps: 1x | turns: 12 | 61.09 s total
#
# ============================================================
# DIJKSTRA A2 config 2
# ============================================================
# Start coord: (17.79, 49.18) -> square cell_id=1981
# Goal  coord: (17.9, 49.24) -> square cell_id=24324
# Start and Goal are outside exclusion zones.
#   [A2 config 2] Building graph (33,239 nodes)... 122,827 direct + 28,937 jump edges (1,151 blocked by can_cross) (3.3 s)
#   [A2 config 2] Turn penalty active: 9 dirs x 21 jumps = 6,282,171 states (~102 MB)
#   [A2 config 2] Running Dijkstra (6,282,171 states)... 3,500,821 expansions (59.3 s)
# Total cost: 2455.0 | 242 cells | ~13,395 m | jumps: 1x | turns: 8 | 62.83 s total

# %%
"""
PPO block - inference on the 50 m costmap with forced coarse steps.
Each action moves ~300 m (virtual 8-directional coarse grid) to reduce zigzagging.
Uses route_results from block 3 (same start/goal, same 50 m costmap).
"""
import importlib
import sys
from pathlib import Path

sys.path.insert(0, str(Path("../").resolve()))

import ppo_routing_cnn
import src.ppo_inference as ppo_inference

importlib.reload(ppo_inference)

AREA_LABEL = globals().get("AREA_LABEL", "A2")
EXCLUSION_PENALTY = globals().get("EXCLUSION_PENALTY", 10)
MAX_JUMPS = globals().get("MAX_JUMPS", 10)
TURN_PENALTY = globals().get("TURN_PENALTY", 1.0)

MODEL_PATH = Path("../ppo_models/coarse300_12km_v4/ppo_routing_final")
PPO_SAMPLE_COUNT = 2
PPO_MAX_ATTEMPTS = 50
PPO_MAX_STEPS = 120
COARSE_STEP_M = 300

ppo_sample_results = ppo_inference.run_ppo_samples_for_scenarios(
    route_results,
    model_path=MODEL_PATH,
    n_samples=PPO_SAMPLE_COUNT,
    max_attempts=PPO_MAX_ATTEMPTS,
    exclusion_penalty=EXCLUSION_PENALTY,
    max_jumps=MAX_JUMPS,
    turn_penalty=TURN_PENALTY,
    max_steps=PPO_MAX_STEPS,
    coarse_step_m=COARSE_STEP_M,
)
# Out:
#   [A2 config 1] Building coarse graph (300 m steps)...
#   Coarse graph (300 m): 32781/33239 nodes reachable, avg 6.2 directions/node
#   Detected torch.compile() artifact - remapping _orig_mod keys...
#   [A2 config 1 attempt 1] PPO: FAILED to reach goal in 120 steps (1.16s)
#   [A2 config 1 attempt 2] PPO: FAILED to reach goal in 42 steps (0.22s)
#   [A2 config 1 attempt 3] PPO: FAILED to reach goal in 120 steps (0.69s)
#   [A2 config 1 attempt 4] PPO: FAILED to reach goal in 56 steps (0.33s)
#   [A2 config 1 attempt 5] PPO: FAILED to reach goal in 120 steps (0.70s)
#   [A2 config 1 attempt 6] PPO: FAILED to reach goal in 120 steps (0.65s)
#   [A2 config 1 attempt 7] PPO: cost=2115.4 | 116 cells | ~35,191 m | jumps=0 | turns=88 | steps=115 | 0.63s
#   [A2 config 1 attempt 8] PPO: FAILED to reach goal in 120 steps (0.66s)
#   [A2 config 1 attempt 9] PPO: FAILED to reach goal in 120 steps (0.70s)
#   [A2 config 1 attempt 10] PPO: FAILED to reach goal in 120 steps (0.59s)
#   [A2 config 1 attempt 11] PPO: FAILED to reach goal in 120 steps (0.64s)
#   [A2 config 1 attempt 12] PPO: FAILED to reach goal in 120 steps (0.64s)
#   [A2 config 1 attempt 13] PPO: FAILED to reach goal in 120 steps (0.64s)
#   [A2 config 1 attempt 14] PPO: FAILED to reach goal in 120 steps (0.74s)
#   [A2 config 1 attempt 15] PPO: FAILED to reach goal in 46 steps (0.26s)
#   [A2 config 1 attempt 16] PPO: FAILED to reach goal in 59 steps (0.32s)
#   [A2 config 1 attempt 17] PPO: FAILED to reach goal in 120 steps (0.65s)
#   [A2 config 1 attempt 18] PPO: FAILED to reach goal in 120 steps (0.62s)
#   [A2 config 1 attempt 19] PPO: FAILED to reach goal in 120 steps (0.65s)
#   [A2 config 1 attempt 20] PPO: FAILED to reach goal in 120 steps (0.62s)
#   [A2 config 1 attempt 21] PPO: FAILED to reach goal in 120 steps (0.68s)
#   [A2 config 1 attempt 22] PPO: FAILED to reach goal in 120 steps (0.72s)
#   [A2 config 1 attempt 23] PPO: FAILED to reach goal in 120 steps (0.67s)
#   [A2 config 1 attempt 24] PPO: FAILED to reach goal in 120 steps (0.64s)
#   [A2 config 1 attempt 25] PPO: FAILED to reach goal in 120 steps (0.64s)
#   [A2 config 1 attempt 26] PPO: FAILED to reach goal in 120 steps (0.62s)
#   [A2 config 1 attempt 27] PPO: FAILED to reach goal in 31 steps (0.18s)
#   [A2 config 1 attempt 28] PPO: FAILED to reach goal in 120 steps (0.64s)
#   [A2 config 1 attempt 29] PPO: FAILED to reach goal in 120 steps (0.62s)
#   [A2 config 1 attempt 30] PPO: FAILED to reach goal in 120 steps (0.64s)
#   [A2 config 1 attempt 31] PPO: FAILED to reach goal in 120 steps (0.65s)
#   [A2 config 1 attempt 32] PPO: FAILED to reach goal in 43 steps (0.22s)
#   [A2 config 1 attempt 33] PPO: FAILED to reach goal in 120 steps (0.66s)
#   [A2 config 1 attempt 34] PPO: FAILED to reach goal in 120 steps (0.67s)
#   [A2 config 1 attempt 35] PPO: FAILED to reach goal in 120 steps (0.70s)
#   [A2 config 1 attempt 36] PPO: FAILED to reach goal in 120 steps (0.58s)
#   [A2 config 1 attempt 37] PPO: FAILED to reach goal in 120 steps (0.65s)
#   [A2 config 1 attempt 38] PPO: FAILED to reach goal in 120 steps (0.67s)
#   [A2 config 1 attempt 39] PPO: FAILED to reach goal in 120 steps (0.68s)
#   [A2 config 1 attempt 40] PPO: FAILED to reach goal in 120 steps (0.69s)
#   [A2 config 1 attempt 41] PPO: FAILED to reach goal in 120 steps (0.78s)
#   [A2 config 1 attempt 42] PPO: FAILED to reach goal in 120 steps (0.90s)
#   [A2 config 1 attempt 43] PPO: FAILED to reach goal in 120 steps (0.69s)
#   [A2 config 1 attempt 44] PPO: FAILED to reach goal in 120 steps (0.74s)
#   [A2 config 1 attempt 45] PPO: FAILED to reach goal in 120 steps (0.88s)
#   [A2 config 1 attempt 46] PPO: FAILED to reach goal in 120 steps (0.65s)
#   [A2 config 1 attempt 47] PPO: FAILED to reach goal in 120 steps (0.61s)
#   [A2 config 1 attempt 48] PPO: FAILED to reach goal in 120 steps (0.62s)
#   [A2 config 1 attempt 49] PPO: FAILED to reach goal in 120 steps (0.58s)
#   [A2 config 1 attempt 50] PPO: FAILED to reach goal in 120 steps (0.62s)
#   [A2 config 1] 1 unique successful routes from 50 attempts
#   [A2 config 2] Building coarse graph (300 m steps)...
#   Coarse graph (300 m): 32781/33239 nodes reachable, avg 6.2 directions/node
#   Detected torch.compile() artifact - remapping _orig_mod keys...
#   [A2 config 2 attempt 1] PPO: FAILED to reach goal in 120 steps (0.61s)
#   [A2 config 2 attempt 2] PPO: FAILED to reach goal in 120 steps (0.61s)
#   [A2 config 2 attempt 3] PPO: FAILED to reach goal in 120 steps (0.53s)
#   [A2 config 2 attempt 4] PPO: FAILED to reach goal in 120 steps (0.57s)
#   [A2 config 2 attempt 5] PPO: FAILED to reach goal in 120 steps (0.57s)
#   [A2 config 2 attempt 6] PPO: FAILED to reach goal in 120 steps (0.53s)
#   [A2 config 2 attempt 7] PPO: FAILED to reach goal in 120 steps (0.55s)
#   [A2 config 2 attempt 8] PPO: FAILED to reach goal in 120 steps (0.61s)
#   [A2 config 2 attempt 9] PPO: FAILED to reach goal in 120 steps (0.58s)
#   [A2 config 2 attempt 10] PPO: FAILED to reach goal in 120 steps (0.58s)
#   [A2 config 2 attempt 11] PPO: FAILED to reach goal in 58 steps (0.31s)
#   [A2 config 2 attempt 12] PPO: FAILED to reach goal in 120 steps (0.57s)
#   [A2 config 2 attempt 13] PPO: FAILED to reach goal in 120 steps (0.55s)
#   [A2 config 2 attempt 14] PPO: FAILED to reach goal in 120 steps (0.57s)
#   [A2 config 2 attempt 15] PPO: FAILED to reach goal in 26 steps (0.15s)
#   [A2 config 2 attempt 16] PPO: FAILED to reach goal in 120 steps (0.61s)
#   [A2 config 2 attempt 17] PPO: FAILED to reach goal in 120 steps (0.53s)
#   [A2 config 2 attempt 18] PPO: cost=1666.6 | 104 cells | ~31,933 m | jumps=0 | turns=76 | steps=103 | 0.47s
#   [A2 config 2 attempt 19] PPO: FAILED to reach goal in 120 steps (0.62s)
#   [A2 config 2 attempt 20] PPO: FAILED to reach goal in 120 steps (0.57s)
#   [A2 config 2 attempt 21] PPO: FAILED to reach goal in 120 steps (0.61s)
#   [A2 config 2 attempt 22] PPO: FAILED to reach goal in 120 steps (0.59s)
#   [A2 config 2 attempt 23] PPO: FAILED to reach goal in 120 steps (0.61s)
#   [A2 config 2 attempt 24] PPO: FAILED to reach goal in 120 steps (0.65s)
#   [A2 config 2 attempt 25] PPO: FAILED to reach goal in 120 steps (0.75s)
#   [A2 config 2 attempt 26] PPO: FAILED to reach goal in 120 steps (0.73s)
#   [A2 config 2 attempt 27] PPO: FAILED to reach goal in 120 steps (0.79s)
#   [A2 config 2 attempt 28] PPO: FAILED to reach goal in 120 steps (0.71s)
#   [A2 config 2 attempt 29] PPO: FAILED to reach goal in 85 steps (0.52s)
#   [A2 config 2 attempt 30] PPO: FAILED to reach goal in 120 steps (0.72s)
#   [A2 config 2 attempt 31] PPO: FAILED to reach goal in 120 steps (0.73s)
#   [A2 config 2 attempt 32] PPO: FAILED to reach goal in 120 steps (0.63s)
#   [A2 config 2 attempt 33] PPO: FAILED to reach goal in 25 steps (0.12s)
#   [A2 config 2 attempt 34] PPO: FAILED to reach goal in 21 steps (0.13s)
#   [A2 config 2 attempt 35] PPO: FAILED to reach goal in 120 steps (0.55s)
#   [A2 config 2 attempt 36] PPO: FAILED to reach goal in 36 steps (0.25s)
#   [A2 config 2 attempt 37] PPO: FAILED to reach goal in 43 steps (0.28s)
#   [A2 config 2 attempt 38] PPO: FAILED to reach goal in 120 steps (0.66s)
#   [A2 config 2 attempt 39] PPO: FAILED to reach goal in 120 steps (0.68s)
#   [A2 config 2 attempt 40] PPO: FAILED to reach goal in 120 steps (0.70s)
#   [A2 config 2 attempt 41] PPO: FAILED to reach goal in 100 steps (0.63s)
#   [A2 config 2 attempt 42] PPO: FAILED to reach goal in 120 steps (0.68s)
#   [A2 config 2 attempt 43] PPO: FAILED to reach goal in 46 steps (0.30s)
#   [A2 config 2 attempt 44] PPO: FAILED to reach goal in 120 steps (0.70s)
#   [A2 config 2 attempt 45] PPO: FAILED to reach goal in 120 steps (0.71s)
#   [A2 config 2 attempt 46] PPO: FAILED to reach goal in 120 steps (0.64s)
#   [A2 config 2 attempt 47] PPO: FAILED to reach goal in 25 steps (0.15s)
#   [A2 config 2 attempt 48] PPO: FAILED to reach goal in 35 steps (0.22s)
#   [A2 config 2 attempt 49] PPO: FAILED to reach goal in 120 steps (0.59s)
#   [A2 config 2 attempt 50] PPO: FAILED to reach goal in 120 steps (0.63s)
#   [A2 config 2] 1 unique successful routes from 50 attempts

# %%
import src.ppo_visualization as ppo_visualization

ppo_visualization.plot_dijkstra_with_ppo_samples(
    ppo_sample_results,
    AREA_LABEL,
    START_LONLAT,
    GOAL_LONLAT,
)
